# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
metrics = pd.read_csv('metrics_by_scenario.csv')
metrics.head()
# Out:
#      scenario       method     score
# 0      simple     spearman  0.813333
# 1      simple  permutation  0.733333
# 2      simple         shap  0.733333
# 3  correlated     spearman  0.693333
# 4  correlated  permutation  0.600000

# %%
plt.style.use('ggplot')
sns.set_style("white")

plt.figure(figsize=(8, 6), dpi=80)
plt.rcParams.update({'font.size': 20})

sns.barplot(data=metrics, x='scenario', y='score', hue='method')
plt.legend(bbox_to_anchor=(1.015, 1))
plt.xlabel("Scenario", labelpad=20)
plt.ylabel("% Correct", labelpad=20)
# Out:
# Text(0, 0.5, '% Correct')
